# %% [raw]
# ---
# title: "OpEx Notes"
# format: html
# jupyter: Win Pyenv3.11.1
# ---

# %%
from openbb import obb

from typing import Literal
from IPython.display import display, clear_output
import ipywidgets as widg
import pandas as pd
import pandas_ta as ta
from datetime import datetime as dt
from plotly import graph_objects as go

# %%
obb.account.login(
    email="eh4468@wayne.edu",
    password="Adidas1989!?!?",
    pat="eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9.eyJhdXRoX3Rva2VuIjoicE81QXg0MHA0a2t3WU1nMHd3cDl4bkRWcXpHbzBmT0g3RmJKNFNmVyIsImV4cCI6MTcyNDY5NjE0NX0.G9bDeCVs7FiRaNj6b0MjMDYYFcT1zSdZHXPvR3 - h8Zw",
    remember_me=True,
)
# obb.account.login(username = ,pat="eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9.eyJhdXRoX3Rva2VuIjoicE81QXg0MHA0a2t3WU1nMHd3cDl4bkRWcXpHbzBmT0g3RmJKNFNmVyIsImV4cCI6MTcyNDY5NjE0NX0.G9bDeCVs7FiRaNj6b0MjMDYYFcT1zSdZHXPvR3 - h8Zw")

# %%
obb.user.credentials
# Out:
# Credentials
#
# benzinga_api_key: None
# biztoc_api_key: None
# fmp_api_key: **********
# fred_api_key: **********
# intrinio_api_key: **********
# nasdaq_api_key: **********
# polygon_api_key: None
# tiingo_token: None
# tradingeconomics_api_key: None

# %%
# obb.user.preferences = "dataframe"

# %%
symbol = "AMD"
options = obb.derivatives.options.chains(symbol, provider="cboe")
options_df = pd.DataFrame[options.model_copy(deep=True)]
# Out:
# OBBject
#
# id: 065becc4-11f4-7587-8000-7f7b2245af53
# results: [{'contract_symbol': 'AMD240209C00075000', 'symbol': None, 'expiration': d...
# provider: cboe
# warnings: None
# chart: None
# extra: {'metadata': {'arguments': {'provider_choices': {'provider': 'cboe'}, 'stand...

# %%
def filter_opts_data(options, by: Literal["expiration", "strike"] = "expiration"):
    data = pd.DataFrame()
    data["Total OI"] = options.groupby(by)["open_interest"].sum()
    data["Call OI"] = (
        options[options["option_type"] == "call"].groupby(by)["open_interest"].sum()
    )
    data["Put OI"] = (
        options[options["option_type"] == "put"].groupby(by)["open_interest"].sum()
    )
    data["Total Volume"] = options.groupby(by)["volume"].sum()
    data["Call Volume"] = (
        options[options["option_type"] == "call"].groupby(by)["volume"].sum()
    )
    data["Put volume"] = (
        options[options["option_type"] == "put"].groupby(by)["volume"].sum()
    )
    return data


data = filter_opts_data(options, "strike")
data
# Out:
#         Total OI  Call OI   Put OI  Total Volume  Call Volume  Put volume
# strike
# 25.0      7129.0   1562.0   5567.0          31.0          9.0        22.0
# 30.0     21466.0    634.0  20832.0         155.0         16.0       139.0
# 35.0      2750.0    240.0   2510.0          15.0         15.0         0.0
# 40.0     13033.0   1245.0  11788.0           9.0          4.0         5.0
# 45.0      9821.0    735.0   9086.0          10.0          0.0        10.0
# ...          ...      ...      ...           ...          ...         ...
# 280.0      634.0    634.0      0.0        1483.0       1483.0         0.0
# 290.0      660.0    660.0      0.0         282.0        282.0         0.0
# 300.0     1286.0   1285.0      1.0        1352.0       1352.0         0.0
# 310.0      479.0    479.0      0.0         234.0        234.0         0.0
# 320.0     1931.0   1929.0      2.0        2121.0       2121.0         0.0
#
# [105 rows x 6 columns]

# %%
fundamental_data = obb.equity.fundamental.ratios(
    symbol, period="quarter", provider="fmp"
)
fundamental_data.index = fundamental_data.index.strftime("%Y-%m-%d")
fundamental_data
# Out:
# ---------------------------------------------------------------------------
# ValidationError                           Traceback (most recent call last)
# File c:\Users\eorlo\.pyenv\pyenv-win\versions\3.11.1\Lib\site-packages\openbb_core\provider\query_executor.py:97, in QueryExecutor.execute(self, provider_name, model_name, params, credentials, **kwargs)
#      96 try:
# ---> 97     return await fetcher.fetch_data(params, filtered_credentials, **kwargs)
#      98 except Exception as e:
#
# File c:\Users\eorlo\.pyenv\pyenv-win\versions\3.11.1\Lib\site-packages\openbb_core\provider\abstract\fetcher.py:87, in Fetcher.fetch_data(cls, params, credentials, **kwargs)
#      84 data = await maybe_coroutine(
#      85     cls.extract_data, query=query, credentials=credentials, **kwargs
#      86 )
# ---> 87 return cls.transform_data(query=query, data=data, **kwargs)
#
# ...

# %%
df_daily = obb.equity.price.historical(symbol, provider="yfinance")
df_daily
# Out:
#               open    high     low   close     volume  dividends  stock_splits
# date
# 2023-01-23   72.22   76.59   71.54   76.53   84293200        0.0           0.0
# 2023-01-24   73.75   75.64   73.42   74.70   60822600        0.0           0.0
# 2023-01-25   72.90   75.12   72.09   74.91   49932600        0.0           0.0
# 2023-01-26   76.50   77.08   74.28   75.16   49583900        0.0           0.0
# 2023-01-27   73.70   76.74   73.49   75.40   58118600        0.0           0.0
# ...            ...     ...     ...     ...        ...        ...           ...
# 2024-01-16  150.36  159.72  149.98  158.74  112711400        0.0           0.0
# 2024-01-17  158.45  160.64  154.40  160.17  104085000        0.0           0.0
# 2024-01-18  166.20  168.60  158.22  162.67  131864900        0.0           0.0
# 2024-01-19  165.80  174.25  162.20  174.23  139825500        0.0           0.0
# 2024-01-22  174.39  174.65  164.15  167.96   97304435        0.0           0.0
#
# ...

# %%
df_daily.head(1)
# Out:
#              open   high    low  close    volume  dividends  stock_splits
# date
# 2023-01-23  72.22  76.59  71.54  76.53  84293200        0.0           0.0

# %%
df_daily = obb.equity.price.historical(
    symbol="spy", start_date="1990-01-01", provider="yfinance"
)
df_daily.head(1)
# Out:
#              open   high    low  close   volume  dividends  stock_splits  \
# date
# 1993-01-29  43.97  43.97  43.75  43.94  1003200        0.0           0.0
#
#             capital_gains
# date
# 1993-01-29            0.0

# %%
df_monthly = obb.equity.price.historical(
    "spy", start_date="1990-01-01", interval="1M", provider="yfinance"
)
df_monthly.tail(2)
# Out:
#               open    high     low   close      volume  dividends  \
# date
# 2023-12-01  455.77  477.55  454.31  475.31  1643108100       1.91
# 2024-01-01  472.16  485.22  466.43  483.95  1144128407       0.00
#
#             stock_splits  capital_gains
# date
# 2023-12-01           0.0            0.0
# 2024-01-01           0.0            0.0

# %%
resampled_df = (
    df_daily[["open", "high", "low", "close", "volume"]]
    .resample("M")
    .agg(
        {"open": "first", "high": "max", "low": "min", "close": "last", "volume": "sum"}
    )
)
resampled_df
# Out:
#               open    high     low   close      volume
# date
# 1993-01-31   43.97   43.97   43.75   43.94     1003200
# 1993-02-28   43.97   45.12   42.81   44.41     5417600
# 1993-03-31   44.56   45.84   44.22   45.19     3019200
# 1993-04-30   45.25   45.25   43.28   44.03     2697200
# 1993-05-31   44.09   45.66   43.84   45.22     1808000
# ...            ...     ...     ...     ...         ...
# 2023-09-30  453.17  453.67  422.29  427.48  1588673200
# 2023-10-31  426.62  438.14  409.21  418.20  1999149700
# 2023-11-30  419.20  458.32  418.65  456.40  1499960600
# 2023-12-31  455.77  477.55  454.31  475.31  1643108100
# 2024-01-31  472.16  485.22  466.43  483.93  1144119079
#
# [373 rows x 5 columns]

# %%
class HistoricalPrices:
    def __init__(self, symbol, start_date, end_date, provider, **kwargs) -> None:
        self.one: pd.DataFrame = (
            obb.equity.price.historical(
                symbol=symbol, start_date=start_date, end_date=end_date, interval="1m"
            )
            .to_df()
            .convert_dtypes()
        )
        self.five: pd.DataFrame = (
            obb.equity.price.historical(
                symbol=symbol, start_date=start_date, end_date=end_date, interval="5m"
            )
            .to_df()
            .convert_dtypes()
        )
        self.fifteen: pd.DataFrame = (
            obb.equity.price.historical(
                symbol=symbol, start_date=start_date, end_date=end_date, interval="15m"
            )
            .to_df()
            .convert_dtypes()
        )
        self.thirty: pd.DataFrame = (
            obb.equity.price.historical(
                symbol=symbol, start_date=start_date, end_date=end_date, interval="30m"
            )
            .to_df()
            .convert_dtypes()
        )
        self.sixty: pd.DataFrame = (
            obb.equity.price.historical(
                symbol=symbol, start_date=start_date, end_date=end_date, interval="60m"
            )
            .to_df()
            .convert_dtypes()
        )
        self.daily: pd.DataFrame = (
            obb.equity.price.historical(
                symbol=symbol, start_date=start_date, end_date=end_date, interval="1d"
            )
            .to_df()
            .convert_dtypes()
        )
        self.weekly: pd.DataFrame = (
            obb.equity.price.historical(
                symbol=symbol, start_date=start_date, end_date=end_date, interval="1W"
            )
            .to_df()
            .convert_dtypes()
        )
        self.monthly: pd.DataFrame = (
            obb.equity.price.historical(
                symbol=symbol, start_date=start_date, end_date=end_date, interval="1M"
            )
            .to_df()
            .convert_dtypes()
        )


def load_historical(
    symbol: str = "",
    start_date=None,
):
    """
    Purpose:
    """
