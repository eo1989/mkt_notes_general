# %%
# from ucimlrepo import fetch_ucirepo
# _dji = fetch_ucirepo(id=312)
# __x = _dji.data.features
# __y = _dji.data.targets
# print(f"metadata: {_dji.metadata}\nvariable information: {_dji.variables}")

# %%
import pandas as pd

# import numpy as np
import statsmodels.api as st
import statsmodels.graphics.tsaplots as tsa

df = pd.read_csv("../_data/dji/dow_jones_index.data")
df.head()
# Out:
#    quarter stock       date    open    high     low   close     volume  \
# 0        1    AA   1/7/2011  $15.82  $16.72  $15.78  $16.42  239655616
# 1        1    AA  1/14/2011  $16.71  $16.71  $15.64  $15.97  242963398
# 2        1    AA  1/21/2011  $16.19  $16.38  $15.60  $15.79  138428495
# 3        1    AA  1/28/2011  $15.87  $16.63  $15.82  $16.13  151379173
# 4        1    AA   2/4/2011  $16.18  $17.39  $16.18  $17.14  154387761
#
#    percent_change_price  percent_change_volume_over_last_wk  \
# 0               3.79267                                 NaN
# 1              -4.42849                            1.380223
# 2              -2.47066                          -43.024959
# 3               1.63831                            9.355500
# 4               5.93325                            1.987452
#
#    previous_weeks_volume next_weeks_open next_weeks_close  \
# 0                    NaN          $16.71           $15.97
# ...

# %% [markdown]
# # Definitions of Time Series
# There are a quite a few different techniques for modeling a time series.

# %%
tsa.plot_pacf(df["percent_change_next_weeks_price"])

# %%
tsa.plot_acf(df["percent_change_next_weeks_price"])
