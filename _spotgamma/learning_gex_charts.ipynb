# %% [raw]
# ---
# title: "Learning Gex Charts"
# format:
#   gfm:
#     code-fold: true
#   html: default
#   typst: default
# categories: ["gex"]
# author: Ernest Orlowski
# jupyter: win_pyenv3.12.0
# execute:
#   cache: true
#   warning: false
# code-link: true
# code-block-border-left:true
# ---

# %%
# noqa
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
from datetime import timedelta, date
import datetime
from itertools import *

plt.style.use("seaborn-v0_8-deep")
sns.set_context("notebook")

# %%
# noqa
_df = pd.read_csv(
    "C:/Users/eorlo/Desktop/spy_quotedata_april24.csv",
    # delimiter="\s+",
    header=1,
    skiprows=2,
)
_df
# print(_df.info())
# Out:
#      Expiration Date               Calls  Last Sale    Net   Bid   Ask  \
# 0    Mon Apr 08 2024  SPY240408C00510000       8.80  0.340  8.90  9.29
# 1    Mon Apr 08 2024  SPY240408C00511000       7.86  0.335  8.01  8.13
# 2    Mon Apr 08 2024  SPY240408C00512000       6.87  0.255  7.02  7.14
# 3    Mon Apr 08 2024  SPY240408C00513000       5.78  0.065  6.04  6.15
# 4    Mon Apr 08 2024  SPY240408C00514000       5.09  0.210  5.06  5.17
# ..               ...                 ...        ...    ...   ...   ...
# 255  Tue Apr 30 2024  SPY240430C00525000       4.37 -0.275  4.37  4.39
# 256  Tue Apr 30 2024  SPY240430C00526000       4.15 -0.065  3.93  3.96
# 257  Tue Apr 30 2024  SPY240430C00527000       3.53 -0.275  3.53  3.55
# 258  Tue Apr 30 2024  SPY240430C00528000       3.27 -0.160  3.15  3.17
# 259  Tue Apr 30 2024  SPY240430C00529000       2.80 -0.275  2.80  2.82
#
#      Volume      IV   Delta   Gamma  ...                Puts  Last Sale.1  \
# ...

# %%
ddf = _df.copy()
first_half = (ddf.filter(regex="^Puts", axis=1).)

# %%
# noqa
# rng = np.random.default_rng()
# _rng = rng.integers(0, 100, size=(100, 4))

# ppdf = pd.DataFrame(_rng, columns=list("ABCD"))
# ppdf
